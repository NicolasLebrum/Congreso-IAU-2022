# %%
cuerpos = []
import pandas as pd
import os
import constants
def main(asteroide,cuerpo):
    import method
    import regression
    return (regression, method,cuerpo)

Tabla_JPL = pd.read_csv('sbdb_query_results.csv')
if __name__ == "__main__":
    for a in range(2):
        constants.Asteroide = Tabla_JPL[Tabla_JPL['number_mp'] == Tabla_JPL['number_mp'][a]]
        asteroide = constants.Asteroide
        constants.cuerpo = asteroide['number_mp'].iloc[0]
        cuerpo = constants.cuerpo
        cuerpos.append(cuerpo)
    main(asteroide,cuerpo)
# Out:
# <style>.container{ widht:90% !important; }<\style>
# <style>.container{ font-size:18px !important; }<\style>
# 0.9998574712257019 0.015209729987790244 0.9982281225448093 1.0751551623543496e-29 0.012427499429102526
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.998
# Model:                            OLS   Adj. R-squared (uncentered):              0.998
# Method:                 Least Squares   F-statistic:                          1.530e+04
# Date:                Mon, 15 Jul 2024   Prob (F-statistic):                    3.50e-35
# Time:                        16:26:22   Log-Likelihood:                          35.056
# No. Observations:                  25   AIC:                                     -68.11
# Df Residuals:                      24   BIC:                                     -66.89
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
